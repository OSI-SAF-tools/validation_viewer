# %%
from __future__ import division
import sys
sys.path.append('../config')
sys.path.append('../viewer')

# %matplotlib inline
from pylab import *
import os
import glob
from pandas import *
from pandas import datetime
import re
import pyresample as pr
from ipywidgets import interactive
import itertools
import plots_daily as pd
import plots_aggregated as pa

# %% [markdown]
# ##### Get the configuration variables

# %%
import config_osi450 as cfg
#from config.config_amsr2 import *
#from config_ssmi import *
#from config_emissivity import *

# %% [markdown]
# ##### Plot the Standard Deviation as a Function of the Date

# %%
# data_dir, output_dir, area_config_path, bin_intervals, results_output
vp = pa.ValidationPlots(cfg.data_dir, cfg.path_to_plots, 
                        cfg.path_area_config, cfg.bin_intervals, cfg.RESULTS_PATHS)
stats = vp.line_plots()
# Save to excel
stats.to_excel('/home/jol/Documents/Programs/data_analaysis/validation/bias_std_amsr2.xls')

# %% [markdown]
# ##### Plot the Within ±10 % and ±20 % Charts

# %%
vp.barcharts(0)

# %% [markdown]
# ### Look at the data for a given day

# %%
reload(pd)
vplots = pd.ValidationPlots(cfg.path_to_hdf5, cfg.path_area_config)

def interact_out(dateidx, plot_type, hemisphere):
    vplots.hemisphere = hemisphere
    getattr(vplots, plot_type)(dateidx)

matplotlib.rcParams.update({'font.size': 10})
plot_types = ['plot_map_with_anolomoly', 'plot_hemisphere', 'plot_kde', 'scatter', 'hex_bin', 'histogram']
hemispheres = ['NH', 'SH']
interactive(interact_out, dateidx=(0, len(vplots.dates)-1, 1), plot_type=plot_types, hemisphere=hemispheres)

# %% [markdown]
# A pivot table for a day

# %%
pt = vplots.dataframe(1)
# Save to File
# pt.to_csv('/home/jol/Documents/temp/ice_summary.csv')

# %% [markdown]
# Plot a given day

# %%
fig = vplots.plot_map_with_anolomoly(0)

# %% [markdown]
# Save the plots

# %%
for hm in ('NH', 'SH'):
    vplots.hemisphere = hm
    for i, vp in enumerate(vplots):
        fig = vp.plot_map_with_anolomoly()
        fig.savefig('/data/jol/temp/pngs/{0}_{1}.png'.format(hm,vp.date))
        fig.clf()
# Out:
# /data/jol/software/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Reading SH data
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-208715ea73e5> in <module>()
#       2     vplots.hemisphere = hm
#       3     for i, vp in enumerate(vplots):
# ----> 4         fig = vp.plot_map_with_anolomoly()
#       5         fig.savefig('/data/jol/temp/pngs/{0}_{1}.png'.format(hm,vp.date))
#       6         fig.clf()
#
# /home/jol/Documents/Programs/sources/validation_viewer/viewer/plots_daily.pyc in plot_map_with_anolomoly(self, dateidx, vmin, vmax)
#     129         palette2 = plt.cm.seismic
#     130         palette2.set_bad(color='k', alpha=0.25)
# --> 131         ref, sat = self.get_day(dateidx)
#     132         im1, bmapax1 = self.plot_hemisphere(self._hemisphere, ax1, sat, cmap=palette1, vmin=0, vmax=vmax)
#     133         Date = self.dates[dateidx]
#
# /home/jol/Documents/Programs/sources/validation_viewer/viewer/plots_daily.pyc in get_day(self, dateidx)
#      51
#      52     def get_day(self, dateidx):
# ---> 53         sat = self.satellite[:, :, dateidx]
#      54         ref = self.reference[:, :, dateidx]
#      55         ref.mask = ref.mask + (ref < 0) + (ref > 100)
#
# /data/jol/software/anaconda2/lib/python2.7/site-packages/numpy/ma/core.pyc in __getitem__(self, indx)
#    3115
#    3116         """
# -> 3117         dout = self.data[indx]
#    3118         # We could directly use ndarray.__getitem__ on self.
#    3119         # But then we would have to modify __array_finalize__ to prevent the
#
# IndexError: index 51 is out of bounds for axis 2 with size 51

# %% [markdown]
# Make gifs of the plots

# %%
# %%bash
# cd /data/jol/temp/pngs/
# convert -loop 0 NH*.png NH.gif
# convert -loop 0 SH*.png SH.gif

# %%
1
# Out:
# 1
